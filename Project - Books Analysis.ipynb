# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
#instializing variable for file that will store investigated file from function read_csv.
DataF = pd.read_csv(r'C:\Users\Lakshya\Downloads\books.csv')

# %%
#Showcasing Data if implied above address is correct for DataSet.
DataF
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                             J.K. Rowling/Mary GrandPré           4.57
# ...

# %% [markdown]
# # Q. What is the size of the dataset?

# %%
# It's an function from Pandas that allow us to find size of the given Dataset :-
DataF.size
# Out:
# 144651

# %% [markdown]
# # Q. How widely do values in the dataset vary?

# %%
# describe is a built-in function of pandas which helps and gives insight of DataSet by calcuating count, mean, std(standard deviation), min(minimum value), ect.
# And as shown below, it showcased varied data from min to max.
DataF.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793649e+04          541.864474
# std    13093.358023   1.124794e+05         2576.174610
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           47.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %% [markdown]
# # Q. What are the typical values in the dataset?

# %%
DataF.mean()
# Out:
# C:\Users\Lakshya\AppData\Local\Temp\ipykernel_18948\1877348292.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   DataF.mean()
# bookID                21310.938887
# ratings_count         17936.490159
# text_reviews_count      541.864474
# dtype: float64

# %% [markdown]
# # Q. Is any observations repeating more frequently than others?

# %% [markdown]
# ###### Initial Readings :-

# %%
# Reading taken before separating the duplicates from DataSet :-
# Its is marked as Initial reading.
DataF
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                             J.K. Rowling/Mary GrandPré           4.57
# ...

# %% [markdown]
# ###### Final readings :-

# %%
# drop_duplicates() function is also an important built-in function of pandas.
# It helps to reduce or remove an duplicate or repeatative data present in DataSet.
# Without taking much time it gives the result in such short time.
DataF.drop_duplicates()
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                             J.K. Rowling/Mary GrandPré           4.57
# ...

# %% [markdown]
# # Q. What is the most popular book by Rating count?

# %%
# filter function is reponsible for filtering the data by given parameters.
books_by_ratings = DataF.filter(['title', 'ratings_count'])

# %%
most_pop = books_by_ratings.sort_values(by = "ratings_count")

# %%
most_pop.tail(1)
# Out:
#                          title  ratings_count
# 10340  Twilight (Twilight  #1)        4597666

# %% [markdown]
# # Q. What is the most popular book?

# %%
gar = DataF.filter(['title', 'average_rating'])
far = gar.sort_values(by = 'average_rating')
far.tail(1)
# Out:
#                                               title average_rating
# 9724  The Irish Anatomist: A Study of Flann O'Brien              5

# %% [markdown]
# # Q. Are there any unusually high or low values in this dataset?

# %% [markdown]
# ###### Unusually Low value :-

# %%
most_pop.head(1)
# Out:
#                                                   title  ratings_count
# 9851  The American Campaign: U.S. Presidential Campa...              0

# %% [markdown]
# ###### Unusually High Value :-

# %%
most_pop.tail(1)
# Out:
#                          title  ratings_count
# 10340  Twilight (Twilight  #1)        4597666

# %% [markdown]
# # Q. What is the most popular book by Average Rating?

# %%
gar = DataF.filter(['title', 'average_rating'])

# %%
far = gar.sort_values(by = 'average_rating')

# %%
far.tail(1)
# Out:
#                                               title average_rating
# 9724  The Irish Anatomist: A Study of Flann O'Brien              5

# %% [markdown]
# # Q. What is the central value of different columns?

# %%
n = len(DataF.index)

# %%
num = int(n/2 + 1)

# %%
var = DataF.head(num)

# %%
var.tail(1)
# Out:
#       bookID             title        authors average_rating       isbn  \
# 5563   20287  Hellstrom's Hive  Frank Herbert           3.69  553144383
#
#         isbn13 language_code num_pages  ratings_count  text_reviews_count  \
# 5563  9.78E+12           eng       312             41                   3
#
#      publication_date          publisher Unnamed: 12
# 5563        3/23/1982  Bantam Books (NY)         NaN

# %% [markdown]
# # Q. Are books with fewer pages rated higher than those with large page counts?

# %%
books_with_higher_pages = DataF.filter(['title', 'average_rating', '  num_pages'])

# %%
books_with_higher_pages
# Out:
#                                                    title average_rating
# 0      Harry Potter and the Half-Blood Prince (Harry ...           4.57
# 1      Harry Potter and the Order of the Phoenix (Har...           4.49
# 2      Harry Potter and the Chamber of Secrets (Harry...           4.42
# 3      Harry Potter and the Prisoner of Azkaban (Harr...           4.56
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...           4.78
# ...                                                  ...            ...
# 11122   Expelled from Eden: A William T. Vollmann Reader           4.06
# 11123                        You Bright and Risen Angels           4.08
# 11124                    The Ice-Shirt (Seven Dreams #1)           3.96
# 11125                                        Poor People           3.72
# 11126                        Las aventuras de Tom Sawyer           3.91
#
# [11127 rows x 2 columns]

# %%
DataF
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                             J.K. Rowling/Mary GrandPré           4.57
# ...

# %%
sep = DataF.loc[:,'  num_pages']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '  num_pages'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sep.sort_values()
